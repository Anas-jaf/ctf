# %%
fakeflag = [125, 112, 121, 120, 127, 114, 86, 73, 96, 119, 113, 116, 104, 111, 110, 69, 109, 97, 77, 116, 102, 102, 119, 70, 98, 99, 108, 120, 88, 69, 116, 106, 107, 117, 121, 101, 98, 126, 75, 88, 118, 87, 99, 112],

"".join([chr(i) for i in fakeflag],)
# for i in fakeflag: 
#     print(chr(i))
# Out:
# '}pyx\x7frVI`wqthonEmaMtffwFbclxXEtjkuyeb~KXvWcp'

# %%
import random
def decode(length, final, seed):
    random.seed(seed)

    _ord = [],
    for i in range(length):
        _ord.append(i)

    random.shuffle(_ord)

    dec = [],
    for i in _ord:
        dec.append(final[i],)

    flag = ""
    for i in dec:
        number = random.randint(1, 30)
        flag += chr(i ^ number)

    return flag

# Given input values
length = 44
final = [125, 112, 121, 120, 127, 114, 86, 73, 96, 119, 113, 116, 104, 111, 110, 69, 109, 97, 77, 116, 102, 102, 119, 70, 98, 99, 108, 120, 88, 69, 116, 106, 107, 117, 121, 101, 98, 126, 75, 88, 118, 87, 99, 112],

# Iterate over seed values from 1 to 255
for seed in range(1, 256):
    decoded_flag = decode(length, final, seed)
    print("Seed:", seed, "Decoded flag:", decoded_flag)
# Out:
# Seed: 1 Decoded flag: ]e~oOhoovdfhg}[PvrGKm~klnvh{xdfjFXydxJw^tizl
# Seed: 2 Decoded flag: SfiuOIey`jzBc{}^lX`s`iQjmaqetIwkleEvc~loT{}h
# Seed: 3 Decoded flag: qnmZ|psvv}bCnmsksnZKEpudVPqjfivoqjiicMQ|rlX
# Seed: 4 Decoded flag: egwUgt`DvzvOE{~RhpmHrwYwmvhio{omzBcyn`bdt]qS
# Seed: 5 Decoded flag: ju~b|ljxRl[iq_}~mp|yceZmwiZigxnc@Kxy]IlxvB
# Seed: 6 Decoded flag: bP`GdjmiiXlM~o`rYunEQvl|xk{tKuFftrP}}e~`zzg
# Seed: 7 Decoded flag: jn|RrpvyeGhJbyvgvm{rmWvRxPJX~dbddsyLBz{imq
# Seed: 8 Decoded flag: mv`wqjmh~xbpqC[tw}uzLpXwN^XW~w|l~anCof}zwiQb
# Seed: 9 Decoded flag: dze`xw~bTlyQvNDqduadt]b\vgijio\xquyx|ecrVJ[
# Seed: 10 Decoded flag: dxlDG`jEsNJJcGug}kksnw|qvrvVCpas`cvFjpcxfmg
# Seed: 11 Decoded flag: abScIB|C[qbeoksselxmmXmtkskt|vj@cs_jv|{}RhV
# Seed: 12 Decoded flag: qLW^r~m[`gcctldA|[}mo_qCiqsqi}jrrRnfLyk|yme
# Seed: 13 Decoded flag: J~`nxu~ct\_gyI@rwO`Bod@qmfnmhwtc||nBcxcuUc
# Seed: 14 Decoded flag: k{t~lzds}pba|laO^nuopabw`vYzrsagAo[vDi`CmY\@
# ...

# %%
lists = [["2323102452", "1196358381", "921818776"],
["924191407", "2552619797", "4078326029"],
["515233099", "3521747412", "2426926589"],
["1224733538", "1160363600", "2766472137"],
["352840306", "1769061456", "591812339"],
["4191741892", "2662203160", "4238346558"],
["755873047", "1643401747", "679007133"],
["673025512", "346901491", "4060594907"],
["4114637869", "1892248959", "2680075788"],
["2092956190", "2403836981", "2903709108"],
["338342988", "1306653502", "3749390318"],
["2271208886", "2131987404", "1762283073"],
["3220050576", "1307672323", "545032245"],
["3537596394", "798469737", "2602247028"],
["3968553760", "2139557775", "4210592834"],
["1393884408", "1167613791", "2868633451"],
["1842606214", "2479001850", "99323787"],
["2803478162", "1358498271", "1379718402"],
